# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Net_Data = pd.read_csv("C:\\Users\\utkar\\Downloads\\netflix_titles.csv")

# %%
Net_Data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## DATA WRANGLING

# %%
Net_Data.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
Net_Data.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
Net_Data.shape
# Out:
# (8807, 12)

# %%
Net_Data.size
# Out:
# 105684

# %%
Net_Data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
Net_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
Net_Data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
Net_Data.columns = ['SHOW_ID', 'CATEGORY', 'TITLE', 'DIRECTOR', 'CAST', 'COUNTRY', 'DATE_ADDED',
       'RELEASE YEAR', 'RATING', 'DURATION', 'LISTED IN', 'DESCRIPTION']

# %% [markdown]
# ## DATA CLEANING
#  - FINDING THE DUPLICATE RECORDS AND NULL VALLUES

# %%
Net_Data.duplicated()   # function to find duplicated values
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %% [markdown]
# - This function only returned the top 5 rows and the bottom 5 rows its has not give the neccessary information required to the  direct duplicate values in a dataset

# %%
Net_Data[Net_Data.duplicated()]  # This formulae will only give that contain duplicate values
# Out:
# Empty DataFrame
# Columns: [SHOW_ID, CATEGORY, TITLE, DIRECTOR, CAST, COUNTRY, DATE_ADDED, RELEASE YEAR, RATING, DURATION, LISTED IN, DESCRIPTION]
# Index: []

# %% [markdown]
# - There are no duplicate values found in a dataset

# %% [markdown]
# # FINDING NULL VALUES

# %%
# Using isnull function will return the series of a boolean values the comfirm null areas
Net_Data.isnull()
# Out:
#       SHOW_ID  CATEGORY  TITLE  DIRECTOR   CAST  COUNTRY  DATE_ADDED  \
# 0       False     False  False     False   True    False       False
# 1       False     False  False      True  False    False       False
# 2       False     False  False     False  False     True       False
# 3       False     False  False      True   True     True       False
# 4       False     False  False      True  False    False       False
# ...       ...       ...    ...       ...    ...      ...         ...
# 8802    False     False  False     False  False    False       False
# 8803    False     False  False      True   True     True       False
# 8804    False     False  False     False  False    False       False
# 8805    False     False  False     False  False    False       False
# 8806    False     False  False     False  False    False       False
#
#       RELEASE YEAR  RATING  DURATION  LISTED IN  DESCRIPTION
# 0            False   False     False      False        False
# ...

# %%
Net_Data.isnull().sum() # This will generate total null values in the dataset
# Out:
# SHOW_ID            0
# CATEGORY           0
# TITLE              0
# DIRECTOR        2634
# CAST             825
# COUNTRY          831
# DATE_ADDED        10
# RELEASE YEAR       0
# RATING             4
# DURATION           3
# LISTED IN          0
# DESCRIPTION        0
# dtype: int64

# %%
 # using seaborn to vizualize the nullvalues in the data set
sns.heatmap(Net_Data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# - FOR 'RIVERDALE', 'LICIFER' AND 'LOST IN SAPCE' FIND THE SHOW ID AND THE SHOW'S DIRECTOR

# %%
Net_Data
# Out:
#      SHOW_ID CATEGORY                  TITLE         DIRECTOR  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
Net_Data[Net_Data["TITLE"].isin(["Lucifer"])]
# Out:
#    SHOW_ID CATEGORY    TITLE DIRECTOR  \
# 82     s83  TV Show  Lucifer      NaN
#
#                                                  CAST        COUNTRY  \
# 82  Tom Ellis, Lauren German, Kevin Alejandro, D.B...  United States
#
#             DATE_ADDED  RELEASE YEAR RATING   DURATION  \
# 82  September 10, 2021          2021  TV-14  6 Seasons
#
#                                  LISTED IN  \
# 82  Crime TV Shows, TV Comedies, TV Dramas
#
#                                           DESCRIPTION
# 82  Bored with being the Lord of Hell, the devil r...

# %%
Net_Data[Net_Data["TITLE"].isin(["Riverdale"])]
# Out:
#     SHOW_ID CATEGORY      TITLE         DIRECTOR  \
# 676    s677  TV Show  Riverdale  Rob Seidenglanz
#
#                                                   CAST        COUNTRY  \
# 676  K.J. Apa, Lili Reinhart, Camila Mendes, Cole S...  United States
#
#         DATE_ADDED  RELEASE YEAR RATING   DURATION  \
# 676  June 19, 2021          2019  TV-14  4 Seasons
#
#                                    LISTED IN  \
# 676  Crime TV Shows, TV Dramas, TV Mysteries
#
#                                            DESCRIPTION
# 676  While navigating the troubled waters of sex, r...

# %%
Net_Data[Net_Data["TITLE"].isin(["Lost in Space"])]
# Out:
#      SHOW_ID CATEGORY          TITLE DIRECTOR  \
# 3106   s3107  TV Show  Lost in Space      NaN
#
#                                                    CAST        COUNTRY  \
# 3106  Molly Parker, Toby Stephens, Max Jenkins, Tayl...  United States
#
#              DATE_ADDED  RELEASE YEAR RATING   DURATION  \
# 3106  December 24, 2019          2019  TV-PG  2 Seasons
#
#                                               LISTED IN  \
# 3106  TV Action & Adventure, TV Dramas, TV Sci-Fi & ...
#
#                                             DESCRIPTION
# 3106  After crash-landing on an alien planet, the Ro...

# %%
Net_Data[Net_Data["TITLE"].isin(["Snowpiercer"])]
# Out:
#     SHOW_ID CATEGORY        TITLE      DIRECTOR  \
# 555    s556    Movie  Snowpiercer  Bong Joon Ho
#
#                                                   CAST  \
# 555  Chris Evans, Song Kang-ho, Ed Harris, John Hur...
#
#                          COUNTRY    DATE_ADDED  RELEASE YEAR RATING DURATION  \
# 555  South Korea, Czech Republic  July 2, 2021          2013      R  126 min
#
#                                              LISTED IN  \
# 555  Action & Adventure, Cult Movies, International...
#
#                                            DESCRIPTION
# 555  The Earth's remaining inhabitants are confined...

# %%
Net_Data[Net_Data["TITLE"].str.contains("Lucifer")]  #Using the str.contains() to filter key word
# Out:
#    SHOW_ID CATEGORY    TITLE DIRECTOR  \
# 82     s83  TV Show  Lucifer      NaN
#
#                                                  CAST        COUNTRY  \
# 82  Tom Ellis, Lauren German, Kevin Alejandro, D.B...  United States
#
#             DATE_ADDED  RELEASE YEAR RATING   DURATION  \
# 82  September 10, 2021          2021  TV-14  6 Seasons
#
#                                  LISTED IN  \
# 82  Crime TV Shows, TV Comedies, TV Dramas
#
#                                           DESCRIPTION
# 82  Bored with being the Lord of Hell, the devil r...

# %%
Net_Data[Net_Data['TITLE'].str.contains("Riverdale")]   #Using the str.contains() to filter key word
# Out:
#     SHOW_ID CATEGORY      TITLE         DIRECTOR  \
# 676    s677  TV Show  Riverdale  Rob Seidenglanz
#
#                                                   CAST        COUNTRY  \
# 676  K.J. Apa, Lili Reinhart, Camila Mendes, Cole S...  United States
#
#         DATE_ADDED  RELEASE YEAR RATING   DURATION  \
# 676  June 19, 2021          2019  TV-14  4 Seasons
#
#                                    LISTED IN  \
# 676  Crime TV Shows, TV Dramas, TV Mysteries
#
#                                            DESCRIPTION
# 676  While navigating the troubled waters of sex, r...

# %%
Net_Data[Net_Data["TITLE"].str.contains("Lost in Space")] #Using the str.contains() to filter key word
# Out:
#      SHOW_ID CATEGORY          TITLE DIRECTOR  \
# 3106   s3107  TV Show  Lost in Space      NaN
#
#                                                    CAST        COUNTRY  \
# 3106  Molly Parker, Toby Stephens, Max Jenkins, Tayl...  United States
#
#              DATE_ADDED  RELEASE YEAR RATING   DURATION  \
# 3106  December 24, 2019          2019  TV-PG  2 Seasons
#
#                                               LISTED IN  \
# 3106  TV Action & Adventure, TV Dramas, TV Sci-Fi & ...
#
#                                             DESCRIPTION
# 3106  After crash-landing on an alien planet, the Ro...

# %%
Net_Data[Net_Data['TITLE'].str.contains("Snowpiercer")]  #Using the str.contains() to filter key word
# Out:
#     SHOW_ID CATEGORY        TITLE      DIRECTOR  \
# 555    s556    Movie  Snowpiercer  Bong Joon Ho
#
#                                                   CAST  \
# 555  Chris Evans, Song Kang-ho, Ed Harris, John Hur...
#
#                          COUNTRY    DATE_ADDED  RELEASE YEAR RATING DURATION  \
# 555  South Korea, Czech Republic  July 2, 2021          2013      R  126 min
#
#                                              LISTED IN  \
# 555  Action & Adventure, Cult Movies, International...
#
#                                            DESCRIPTION
# 555  The Earth's remaining inhabitants are confined...

# %% [markdown]
# - WHAT YEAR WERE THE HIGHEST NO. OF MOVIES AND SHOWS RELEASED?

# %%
Net_Data.dtypes
# Out:
# SHOW_ID         object
# CATEGORY        object
# TITLE           object
# DIRECTOR        object
# CAST            object
# COUNTRY         object
# DATE_ADDED      object
# RELEASE YEAR     int64
# RATING          object
# DURATION        object
# LISTED IN       object
# DESCRIPTION     object
# dtype: object

# %%
pd.to_datetime(Net_Data['DATE_ADDED'])
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: DATE_ADDED, Length: 8807, dtype: datetime64[ns]

# %%
Net_Data['RELEASE_DATE'] = pd.to_datetime(Net_Data['DATE_ADDED'])  #convert release columns into Datetime

# %%
Net_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SHOW_ID       8807 non-null   object
#  1   CATEGORY      8807 non-null   object
#  2   TITLE         8807 non-null   object
#  3   DIRECTOR      6173 non-null   object
#  4   CAST          7982 non-null   object
#  5   COUNTRY       7976 non-null   object
#  6   DATE_ADDED    8797 non-null   object
#  7   RELEASE YEAR  8807 non-null   int64
#  8   RATING        8803 non-null   object
#  9   DURATION      8804 non-null   object
#  10  LISTED IN     8807 non-null   object
#  11  DESCRIPTION   8807 non-null   object
#  12  RELEASE_DATE  8797 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 894.6+ KB

# %%
Net_Data
# Out:
#      SHOW_ID CATEGORY                  TITLE         DIRECTOR  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
Net_Data["RELEASE_DATE"].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: RELEASE_DATE, dtype: int64

# %% [markdown]
# - Year 2018 has the highest number of movies and shows releases with 1147 in total

# %%
Net_Data["RELEASE_DATE"].dt.year.value_counts().plot(kind = "bar", color= "Teal" )
plt.xlabel("YEAR", fontsize = 15)
plt.ylabel("FREQUENCY", fontsize= 15)
plt.title("MOVIE RELEASE YEAR")
plt.show()

# %% [markdown]
# - HOW MANY MOVIES AND SHOWS ARE PRESENT IN THE DATASET?

# %%
Net_Data.groupby("CATEGORY").CATEGORY.count()
# Out:
# CATEGORY
# Movie      6131
# TV Show    2676
# Name: CATEGORY, dtype: int64

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
sns.countplot(Net_Data["CATEGORY"])
# Out:
# <AxesSubplot:xlabel='CATEGORY', ylabel='count'>

# %% [markdown]
# - WHAT MOVIES AND WHERE RELEASED IN YEAR 2021?

# %%
Net_Data["RELEASE YEAR"] = Net_Data["RELEASE_DATE"].dt.year

# %%
Net_Data[(Net_Data["CATEGORY"] == "Movie") & (Net_Data["RELEASE YEAR"]== 2021)]
# Out:
#      SHOW_ID CATEGORY                                           TITLE  \
# 0         s1    Movie                            Dick Johnson Is Dead
# 6         s7    Movie                My Little Pony: A New Generation
# 7         s8    Movie                                         Sankofa
# 9        s10    Movie                                    The Starling
# 12       s13    Movie                                    Je Suis Karl
# ...      ...      ...                                             ...
# 8187   s8188    Movie                          The American President
# 8272   s8273    Movie                                    The Departed
# 8320   s8321    Movie                 The Girl with the Dragon Tattoo
# 8434   s8435    Movie  The Naked Gun: From the Files of Police Squad!
# 8461   s8462    Movie                               The Polar Express
#
#                            DIRECTOR  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# ...

# %% [markdown]
# - TITLES OF MOVIES RELEASED IN UNITED STATES

# %%
Net_Data[(Net_Data["CATEGORY"] == "Movie") & (Net_Data["COUNTRY"] == "United States")]
# Out:
#      SHOW_ID CATEGORY                 TITLE          DIRECTOR  \
# 0         s1    Movie  Dick Johnson Is Dead   Kirsten Johnson
# 9        s10    Movie          The Starling    Theodore Melfi
# 27       s28    Movie             Grown Ups      Dennis Dugan
# 28       s29    Movie            Dark Skies     Scott Stewart
# 41       s42    Movie                  Jaws  Steven Spielberg
# ...      ...      ...                   ...               ...
# 8791   s8792    Movie           Young Adult     Jason Reitman
# 8793   s8794    Movie  Yours, Mine and Ours      Raja Gosnell
# 8802   s8803    Movie                Zodiac     David Fincher
# 8804   s8805    Movie            Zombieland   Ruben Fleischer
# 8805   s8806    Movie                  Zoom      Peter Hewitt
#
#                                                    CAST        COUNTRY  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %% [markdown]
# - TITLES OF MOVIES RELEASED IN INDIA

# %%
Net_Data[(Net_Data["CATEGORY"] == "Movie") & (Net_Data["COUNTRY"] == "India")]
# Out:
#      SHOW_ID CATEGORY                  TITLE                 DIRECTOR  \
# 24       s25    Movie                  Jeans               S. Shankar
# 105     s106    Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114     s115    Movie                 Anjaam             Rahul Rawail
# 116     s117    Movie                 Dhanak          Nagesh Kukunoor
# 118     s119    Movie                Gurgaon            Shanker Raman
# ...      ...      ...                    ...                      ...
# 8772   s8773    Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773   s8774    Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798   s8799    Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                  Zenda           Avadhoot Gupte
# 8806   s8807    Movie                 Zubaan              Mozez Singh
#
#                                                    CAST COUNTRY  \
# ...

# %% [markdown]
# - TITLES OF TV SHOWS RELEASED IN INDIA

# %%
Net_Data[(Net_Data["CATEGORY"] == "TV Show") & (Net_Data["COUNTRY"] == "India")]
# Out:
#      SHOW_ID CATEGORY                               TITLE DIRECTOR  \
# 4         s5  TV Show                        Kota Factory      NaN
# 39       s40  TV Show                        Chhota Bheem      NaN
# 50       s51  TV Show                       Dharmakshetra      NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69       s70  TV Show      Stories by Rabindranath Tagore      NaN
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray      NaN
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349   s8350  TV Show              The House That Made Me      NaN
# 8775   s8776  TV Show                     Yeh Meri Family      NaN
#
#                                                    CAST COUNTRY  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# ...

# %%
Net_Data[(Net_Data["CATEGORY"] == "TV Show") & (Net_Data["COUNTRY"] == "India")] ["TITLE"]
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: TITLE, Length: 79, dtype: object

# %%
filtered_Net_Data = Net_Data[(Net_Data['CATEGORY']== 'TV Show') & (Net_Data['COUNTRY']== 'India')]
titles = filtered_Net_Data['TITLE'].values

for i, title in enumerate(titles):
    plt.text(0, i, title, fontsize=12)

plt.yticks([])
plt.title("TV Shows from India", fontsize=15)
plt.show()

# %% [markdown]
# - TOP 10 DIRECTORS WITH THE HIGHEST NO. OF REALISED TV SHOWS AND MOVIES ON NETFLIX

# %%
Net_Data["DIRECTOR"].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: DIRECTOR, dtype: int64

# %%
#Plot the pie chart
plt.figure(figsize= (10,6))
Net_Data['DIRECTOR'].value_counts().head(15).plot(kind='pie', autopct= "%0.2F%%").set_title('TOP 15 DIRECTORS WITH HIGHEST TV SHOW ON NETFLIX', fontsize=13)
plt.show()

# %%
#Plot the pie chart
plt.figure(figsize= (9,6))
Net_Data['DIRECTOR'].value_counts().head(15).plot(kind="bar", color = "Teal").set_title('TOP 15 DIRECTORS WITH HIGHEST TV SHOW ON NETFLIX', fontsize=13)
plt.show()

# %% [markdown]
# - Show data, where Categories, Type and country columns are equal to movie, comedy and INDIA respectivly

# %%
Net_Data.head()
# Out:
#   SHOW_ID CATEGORY                  TITLE         DIRECTOR  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 CAST        COUNTRY  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            DATE_ADDED  RELEASE YEAR RATING   DURATION  \
# 0  September 25, 2021        2021.0  PG-13     90 min
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
# ...

# %%
Net_Data [(Net_Data['CATEGORY']== 'Movie') &(Net_Data['LISTED IN']== 'Comedies') | (Net_Data['COUNTRY']== 'India')]
# Out:
#      SHOW_ID CATEGORY                TITLE                 DIRECTOR  \
# 4         s5  TV Show         Kota Factory                      NaN
# 24       s25    Movie                Jeans               S. Shankar
# 27       s28    Movie            Grown Ups             Dennis Dugan
# 39       s40  TV Show         Chhota Bheem                      NaN
# 50       s51  TV Show        Dharmakshetra                      NaN
# ...      ...      ...                  ...                      ...
# 8773   s8774    Movie  Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show      Yeh Meri Family                      NaN
# 8798   s8799    Movie             Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                Zenda           Avadhoot Gupte
# 8806   s8807    Movie               Zubaan              Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...

# %% [markdown]
# - Show data, where Categories, Type and country columns are equal to movie, comedy and United Kingdom respectivly

# %%
Net_Data [(Net_Data['CATEGORY']== 'Movies') &(Net_Data['LISTED IN']== 'Comedies') | (Net_Data['COUNTRY']== 'United Kingdom')]
# Out:
#      SHOW_ID CATEGORY                                   TITLE  \
# 8         s9  TV Show           The Great British Baking Show
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# 98       s99  TV Show               Octonauts: Above & Beyond
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              DIRECTOR                                               CAST  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %% [markdown]
# - HOW MANY MOVIES AND TV SHOWS WAS HENRY CAVIL CAST IN?

# %%
Net_Data[Net_Data["CAST"].str.contains("Henry Cavill", na=False)]
# Out:
#      SHOW_ID CATEGORY                                    TITLE  \
# 1959   s1960    Movie                             Enola Holmes
# 2058   s2059  TV Show  The Witcher: A Look Inside the Episodes
# 2095   s2096    Movie                       Making The Witcher
# 3117   s3118  TV Show                              The Witcher
# 5522   s5523    Movie                              Sand Castle
# 8539   s8540  TV Show                               The Tudors
#
#               DIRECTOR                                               CAST  \
# 1959    Harry Bradbeer  Millie Bobby Brown, Henry Cavill, Sam Claflin,...
# 2058               NaN  Henry Cavill, Anya Chalotra, Freya Allan, Laur...
# 2095      Nathan Wiley  Henry Cavill, Anya Chalotra, Freya Allan, Eamo...
# 3117               NaN  Henry Cavill, Anya Chalotra, Freya Allan, Jodh...
# 5522  Fernando Coimbra  Nicholas Hoult, Logan Marshall-Green, Henry Ca...
# 8539               NaN  Jonathan Rhys Meyers, Henry Cavill, James Frai...
#
# ...

# %% [markdown]
# - HOW MANY MOVIES AND TV SHOWS WAS VICKY KAUSHAL CAST IN?

# %%
Net_Data[Net_Data["CAST"].str.contains("Vicky Kaushal", na=False)]
# Out:
#      SHOW_ID CATEGORY                 TITLE  \
# 1678   s1679    Movie      Raman Raghav 2.0
# 4507   s4508    Movie                 Sanju
# 4825   s4826    Movie          Lust Stories
# 5040   s5041    Movie  Love Per Square Foot
# 8806   s8807    Movie                Zubaan
#
#                                                DIRECTOR  \
# 1678                                     Anurag Kashyap
# 4507                                    Rajkumar Hirani
# 4825  Zoya Akhtar, Karan Johar, Anurag Kashyap, Diba...
# 5040                                       Anand Tiwari
# 8806                                        Mozez Singh
#
#                                                    CAST COUNTRY  \
# 1678  Nawazuddin Siddiqui, Vicky Kaushal, Sobhita Dh...   India
# 4507  Ranbir Kapoor, Vicky Kaushal, Paresh Rawal, So...   India
# 4825  Vicky Kaushal, Bhumi Pednekar, Radhika Apte, N...   India
# 5040  Vicky Kaushal, Angira Dhar, Alankrita Sahai, R...   India
# ...

# %% [markdown]
# - What are the diffrent ratings defined by Netflix?

# %%
Net_Data.RATING.nunique()
# Out:
# 17

# %% [markdown]
# - How Many movies have the 'TV-14' rating in United states?

# %%
Net_Data.RATING.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# - How Many movies have the 'TV-MA' rating in INDIA?

# %%
Net_Data.RATING.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# - How Many TV Shows has the "R" Rating IN 2020?

# %%
Net_Data[(Net_Data["RATING"] == "R") & (Net_Data["RELEASE YEAR"]==2020)]
# Out:
#      SHOW_ID CATEGORY                     TITLE           DIRECTOR  \
# 1501   s1502    Movie         After We Collided       Roger Kumble
# 1510   s1511    Movie             The Con Is On       James Haslam
# 1515   s1516    Movie               Guest House       Sam Macaroni
# 1517   s1518    Movie  Ma Rainey's Black Bottom    George C. Wolfe
# 1524   s1525    Movie                    Braven         Lin Oeding
# ...      ...      ...                       ...                ...
# 8526   s8527    Movie   The Talented Mr. Ripley  Anthony Minghella
# 8637   s8638    Movie                    Trumbo          Jay Roach
# 8664   s8665    Movie             Up in the Air      Jason Reitman
# 8689   s8690    Movie                Waiting...     Rob McKittrick
# 8703   s8704    Movie       We Are Your Friends         Max Joseph
#
#                                                    CAST  \
# 1501  Josephine Langford, Hero Fiennes Tiffin, Dylan...
# ...

# %% [markdown]
# - How Many TV Shows has the "R" Rating after 2020?

# %%
Net_Data[(Net_Data["RATING"] == "R") & (Net_Data["RELEASE YEAR"] < 2020)]
# Out:
#      SHOW_ID CATEGORY                   TITLE  \
# 3097   s3098    Movie      Doom: Annihilation
# 3100   s3101    Movie  Jarhead: Law of Return
# 3101   s3102    Movie                    MFKZ
# 3107   s3108    Movie          Jacob's Ladder
# 3125   s3126    Movie         The Danish Girl
# ...      ...      ...                     ...
# 8765   s8766    Movie                      XX
# 8768   s8769    Movie       Y Tu Mamá También
# 8791   s8792    Movie             Young Adult
# 8802   s8803    Movie                  Zodiac
# 8804   s8805    Movie              Zombieland
#
#                                                DIRECTOR  \
# 3097                                        Tony Giglio
# 3100                                   Don Michael Paul
# 3101                  Shojiro Nishimi, Guillaume Renard
# 3107                                 David M. Rosenthal
# 3125                                         Tom Hooper
# ...                                                 ...
# ...

# %% [markdown]
# - Find the maximum duration of a Movie or Show in Netflix?

# %%
Net_Data["DURATION"].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
Net_Data[["Minutes", "Unit"]] = Net_Data["DURATION"].str.split(" ", expand = True)

# %%
Net_Data.head()
# Out:
#   SHOW_ID CATEGORY                  TITLE         DIRECTOR  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 CAST        COUNTRY  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            DATE_ADDED  RELEASE YEAR RATING   DURATION  \
# 0  September 25, 2021        2021.0  PG-13     90 min
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
# ...

# %%
NET_DATA_TV = Net_Data[Net_Data["CATEGORY"]== "TV Show"]

# %%
Net_Data.head(2)
# Out:
#   SHOW_ID CATEGORY                 TITLE         DIRECTOR  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 CAST        COUNTRY  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            DATE_ADDED  RELEASE YEAR RATING   DURATION  \
# 0  September 25, 2021        2021.0  PG-13     90 min
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
#
#                                          LISTED IN  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          DESCRIPTION RELEASE_DATE Minutes  \
# 0  As her father nears the end of his life, filmm...   2021-09-25      90
# 1  After crossing paths at a party, a Cape Town t...   2021-09-24       2
#
#       Unit
# 0      min
# ...

# %%
NET_DATA_TV["COUNTRY"].value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: COUNTRY, Length: 196, dtype: int64

# %%
NET_DATA_TV["COUNTRY"].value_counts().head()
# Out:
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Name: COUNTRY, dtype: int64

# %%
# PLOT A BAR GRAPH
plt.figure(figsize=(9,5))
sns.countplot(data = Net_Data, x= "COUNTRY", order = NET_DATA_TV["COUNTRY"].value_counts().head().index )
plt.xlabel("COUNTRY", fontsize= 10)
plt.ylabel("FREQUENCY", fontsize= 10)
plt.title("TOP 5 FREQUENT COUNTRIES")
plt.show()

# %% [markdown]
# - SORT THE DATASET BY YEAR

# %%
Net_Data.sort_values(by = 'RELEASE YEAR', ascending = False).head(2)
# Out:
#     SHOW_ID CATEGORY                 TITLE         DIRECTOR  \
# 0        s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 996    s997    Movie            HOMUNCULUS  Takashi Shimizu
#
#                                                   CAST        COUNTRY  \
# 0                                                  NaN  United States
# 996  Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...          Japan
#
#              DATE_ADDED  RELEASE YEAR RATING DURATION  \
# 0    September 25, 2021        2021.0  PG-13   90 min
# 996      April 22, 2021        2021.0  TV-MA  116 min
#
#                                           LISTED IN  \
# 0                                     Documentaries
# 996  Horror Movies, International Movies, Thrillers
#
#                                            DESCRIPTION RELEASE_DATE Minutes  \
# 0    As her father nears the end of his life, filmm...   2021-09-25      90
# 996  Truth and illusion blurs when a homeless amnes...   2021-04-22     116
#
# ...
